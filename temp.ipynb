# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def f(x):
    return np.sin(2*np.cos(x) - 3*np.sin(x))

# %%
X = 10*np.random.random(50)
Y = f(X)

plt.scatter(X,Y)
plt.show()
